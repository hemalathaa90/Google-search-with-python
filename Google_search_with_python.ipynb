# %%
pip install google

# %%
from googlesearch import search
query="Machine Learning"
for i in search(query,tld='co.in',lang='en',num=10,start=0,stop=None,pause=2):
  print(i)
# Out:
# https://expertsystem.com/machine-learning-definition/?sa=X&ved=2ahUKEwiYubXS0NLrAhVOXM0KHXAPAFgQ9QF6BAgJEAI
# https://expertsystem.com/machine-learning-definition/
# https://www.europeanbusinessreview.com/capturing-data-the-smart-way-supervised-machine-learning/
# https://en.wikipedia.org/wiki/Machine_learning
# https://en.wikipedia.org/wiki/Outline_of_machine_learning
# https://en.wikipedia.org/wiki/Timeline_of_machine_learning
# https://en.wikipedia.org/wiki/Supervised_learning
# https://www.coursera.org/learn/machine-learning
# https://www.coursera.org/learn/machine-learning#about
# https://www.coursera.org/learn/machine-learning#instructors
# https://www.coursera.org/learn/machine-learning#syllabus
# https://www.sas.com/en_us/insights/analytics/machine-learning.html
# https://www.technologyreview.com/2018/11/17/103781/what-is-machine-learning-we-drew-you-another-flowchart/
# https://scitechdaily.com/nasa-using-machine-learning-ai-to-predict-hurricane-intensity/
# ...
